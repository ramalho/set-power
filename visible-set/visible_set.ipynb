# %% [markdown]
# # VisiSet
#
# A set-like collection backed by a numpy structured array with two columns:
# `hash` (`int64`) and `value` (`object`).
#
# Jupyter renders instances as numpy-style tables showing the internal hash/value pairs.

# %%
from visiset import VisiSet

# %% [markdown]
# ## Examples

# %%
vs = VisiSet([10, 20, 30, 40, 50])
vs
# Out:
# VisiSet({40, 10, 50, 20, 30})

# %%
VisiSet(['apple', 'banana', 'cherry'])
# Out:
# VisiSet({'apple', 'banana', 'cherry'})

# %%
VisiSet([3.14, True, (1, 2), frozenset({10, 20})])
# Out:
# VisiSet({True, frozenset({10, 20}), 3.14, (1, 2)})

# %% [markdown]
# ### Set interface

# %%
vs = VisiSet(['a', 'b', 'c'])
vs.add('d')
vs.add('b')  # duplicate — ignored
vs
# Out:
# VisiSet({'b', 'a', 'd', 'c'})

# %%
'b' in vs, 'z' in vs
# Out:
# (True, False)

# %%
len(vs)
# Out:
# 4

# %%
list(vs)
# Out:
# ['b', 'a', 'd', 'c']

# %% [markdown]
# ### Plain text repr

# %%
print(repr(vs))
# Out:
# VisiSet({'b', 'a', 'd', 'c'})

# %% [markdown]
# ## Demo

# %%
v = VisiSet()
v
# Out:
# VisiSet({})

# %%
v.add('Alice')
v
# Out:
# VisiSet({'Alice'})

# %%
v.add('Bob')
v
# Out:
# VisiSet({'Alice', 'Bob'})

# %%
v.add('Carla')
v
# Out:
# VisiSet({'Alice', 'Carla', 'Bob'})

# %%
v.add('Diego')
v
# Out:
# VisiSet({'Alice', 'Carla', 'Diego', 'Bob'})

# %%
v.add('Elise')
v
# Out:
# VisiSet({'Alice', 'Carla', 'Diego', 'Bob', 'Elise'})

# %%
v.add('Fred')
v
# Out:
# VisiSet({'Fred', 'Alice', 'Carla', 'Diego', 'Bob', 'Elise'})

# %%
for c in 'GHIJ':
    v.add(c)
v
# Out:
# VisiSet({'Fred', 'G', 'J', 'I', 'Alice', 'Carla', 'Diego', 'Bob', 'Elise', 'H'})

# %%
v.add('ZZZ')
v
# Out:
# VisiSet({'I', 'ZZZ', 'Carla', 'Diego', 'Bob', 'H', 'Fred', 'G', 'J', 'Alice', 'Elise'})
