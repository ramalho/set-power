# %% [markdown]
# # VisiSet
#
# A set-like collection backed by a numpy structured array with two columns:
# `hash` (`int64`) and `value` (`object`).
#
# Jupyter renders instances as numpy-style tables showing the internal hash/value pairs.

# %%
from visiset import VisiSet

# %% [markdown]
# ## Examples

# %%
VisiSet([0, 1, -1, 2, -2], hash_base=10)
# Out:
# VisiSet({0, 1, 2, -1, -2})

# %%
VisiSet([0, 1, 7, -2, -1])
# Out:
# VisiSet({0, 1, -1, -2, 7})

# %%
VisiSet(['açaí', 'banana', 'cherry', 'bananA'], hash_base=2)
# Out:
# VisiSet({'açaí', 'cherry', 'bananA', 'banana'})

# %%
VisiSet([3.14, True, (1, 2), frozenset({10, 20}), 'Lua'])
# Out:
# VisiSet({'Lua', True, frozenset({10, 20}), 3.14, (1, 2)})

# %% [markdown]
# ### Set interface

# %%
vs = VisiSet(['a', 'b', 'c'])
vs.add('d')
vs.add('b')  # duplicate — ignored
vs
# Out:
# VisiSet({'d', 'a', 'b', 'c'})

# %%
'b' in vs, 'z' in vs
# Out:
# (True, False)

# %%
len(vs)
# Out:
# 4

# %%
list(vs)
# Out:
# ['d', 'a', 'b', 'c']

# %% [markdown]
# ### Plain text repr

# %%
print(repr(vs))
# Out:
# VisiSet({'d', 'a', 'b', 'c'})

# %% [markdown]
# ## Demo with strings

# %%
v = VisiSet()
v
# Out:
# VisiSet({})

# %%
v.add('Alice')
v
# Out:
# VisiSet({'Alice'})

# %%
v.add('Bob')
v
# Out:
# VisiSet({'Bob', 'Alice'})

# %%
v.add('Carla')
v
# Out:
# VisiSet({'Bob', 'Carla', 'Alice'})

# %%
v.add('Diego')
v
# Out:
# VisiSet({'Bob', 'Diego', 'Carla', 'Alice'})

# %%
v.add('Elise')
v
# Out:
# VisiSet({'Bob', 'Diego', 'Elise', 'Carla', 'Alice'})

# %%
v.add('Fred')
v
# Out:
# VisiSet({'Diego', 'Carla', 'Alice', 'Elise', 'Fred', 'Bob'})

# %%
v.union('Gina Homer Ian Jane'.split())
# Out:
# VisiSet({'Bob', 'Homer', 'Ian', 'Jane', 'Carla', 'Alice', 'Gina', 'Elise', 'Fred', 'Diego'})

# %%
v.add('Zeta')
v
# Out:
# VisiSet({'Diego', 'Carla', 'Alice', 'Elise', 'Fred', 'Zeta', 'Bob'})

# %% [markdown]
# ## Demo with numbers

# %%
v = VisiSet([10, 20, 30, 40])
v
# Out:
# VisiSet({40, 10, 20, 30})

# %%
v.add(50)
v
# Out:
# VisiSet({40, 10, 50, 20, 30})

# %%
v.add(2)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(2.0)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(15)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30, 15})

# %%
v.add(31)
v
# Out:
# VisiSet({31, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(47)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(63)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 63, 40, 10, 30, 15})

# %%
v.add(79)
v
# Out:
# VisiSet({63, 2, 40, 10, 47, 15, 79, 50, 20, 30, 31})
