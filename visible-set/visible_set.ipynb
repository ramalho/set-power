# %% [markdown]
# # VisiSet
#
# A set-like collection backed by a numpy structured array with two columns:
# `hash` (`int64`) and `value` (`object`).
#
# Jupyter renders instances as numpy-style tables showing the internal hash/value pairs.

# %%
from visiset import VisiSet

# %% [markdown]
# ## Examples

# %%
vs = VisiSet([10, 20, 30, 40, 50])
vs
# Out:
# VisiSet({40, 10, 50, 20, 30})

# %%
VisiSet(['apple', 'banana', 'cherry'])
# Out:
# VisiSet({'apple', 'cherry', 'banana'})

# %%
VisiSet([3.14, True, (1, 2), frozenset({10, 20})])
# Out:
# VisiSet({True, frozenset({10, 20}), 3.14, (1, 2)})

# %% [markdown]
# ### Set interface

# %%
vs = VisiSet(['a', 'b', 'c'])
vs.add('d')
vs.add('b')  # duplicate — ignored
vs
# Out:
# VisiSet({'c', 'b', 'a', 'd'})

# %%
'b' in vs, 'z' in vs
# Out:
# (True, False)

# %%
len(vs)
# Out:
# 4

# %%
list(vs)
# Out:
# ['c', 'b', 'a', 'd']

# %% [markdown]
# ### Plain text repr

# %%
print(repr(vs))
# Out:
# VisiSet({'c', 'b', 'a', 'd'})

# %% [markdown]
# ## Demo with strings

# %%
v = VisiSet()
v
# Out:
# VisiSet({})

# %%
v.add('Alice')
v
# Out:
# VisiSet({'Alice'})

# %%
v.add('Bob')
v
# Out:
# VisiSet({'Bob', 'Alice'})

# %%
v.add('Carla')
v
# Out:
# VisiSet({'Bob', 'Alice', 'Carla'})

# %%
v.add('Diego')
v
# Out:
# VisiSet({'Diego', 'Bob', 'Alice', 'Carla'})

# %%
v.add('Elise')
v
# Out:
# VisiSet({'Diego', 'Bob', 'Alice', 'Carla', 'Elise'})

# %%
v.add('Fred')
v
# Out:
# VisiSet({'Diego', 'Bob', 'Fred', 'Alice', 'Carla', 'Elise'})

# %%
for c in 'GHIJ':
    v.add(c)
v
# Out:
# VisiSet({'I', 'J', 'H', 'Diego', 'G', 'Bob', 'Fred', 'Alice', 'Carla', 'Elise'})

# %%
v.add('ZZZ')
v
# Out:
# VisiSet({'ZZZ', 'Bob', 'Fred', 'J', 'Alice', 'Carla', 'Elise', 'H', 'Diego', 'G', 'I'})

# %% [markdown]
# ## Demo with numbers

# %%
v = VisiSet([10, 20, 30, 40])
v
# Out:
# VisiSet({40, 10, 20, 30})

# %%
v.add(50)
v
# Out:
# VisiSet({40, 10, 50, 20, 30})

# %%
v.add(2)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(2.0)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(15)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30, 15})

# %%
v.add(31)
v
# Out:
# VisiSet({31, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(47)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(63)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 63, 40, 10, 30, 15})

# %%
v.add(79)
v
# Out:
# VisiSet({63, 2, 40, 10, 47, 15, 79, 50, 20, 30, 31})
