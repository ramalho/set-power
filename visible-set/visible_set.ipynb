# %% [markdown]
# # VisiSet
#
# A set-like collection backed by a numpy structured array with two columns:
# `hash` (`int64`) and `value` (`object`).
#
# Jupyter renders instances as numpy-style tables showing the internal hash/value pairs.

# %%
from visiset import VisiSet

# %% [markdown]
# ## Examples

# %%
vs = VisiSet([10, 20, 30, 40, 50])
vs
# Out:
# VisiSet({40, 10, 50, 20, 30})

# %%
VisiSet(['apple', 'banana', 'cherry'])
# Out:
# VisiSet({'banana', 'apple', 'cherry'})

# %%
VisiSet([3.14, True, (1, 2), frozenset({10, 20})])
# Out:
# VisiSet({True, frozenset({10, 20}), 3.14, (1, 2)})

# %% [markdown]
# ### Set interface

# %%
vs = VisiSet(['a', 'b', 'c'])
vs.add('d')
vs.add('b')  # duplicate — ignored
vs
# Out:
# VisiSet({'b', 'a', 'c', 'd'})

# %%
'b' in vs, 'z' in vs
# Out:
# (True, False)

# %%
len(vs)
# Out:
# 4

# %%
list(vs)
# Out:
# ['b', 'a', 'c', 'd']

# %% [markdown]
# ### Plain text repr

# %%
print(repr(vs))
# Out:
# VisiSet({'b', 'a', 'c', 'd'})

# %% [markdown]
# ## Demo

# %%
v = VisiSet()
v
# Out:
# VisiSet({})

# %%
v.add('Alice')
v
# Out:
# VisiSet({'Alice'})

# %%
v.add('Bob')
v
# Out:
# VisiSet({'Bob', 'Alice'})

# %%
v.add('Carla')
v
# Out:
# VisiSet({'Bob', 'Carla', 'Alice'})

# %%
v.add('Diego')
v
# Out:
# VisiSet({'Bob', 'Carla', 'Alice', 'Diego'})

# %%
v.add('Elise')
v
# Out:
# VisiSet({'Bob', 'Carla', 'Alice', 'Diego', 'Elise'})

# %%
v.add('Fred')
v
# Out:
# VisiSet({'Bob', 'Alice', 'Elise', 'Fred', 'Carla', 'Diego'})

# %%
for c in 'GHIJ':
    v.add(c)
v
# Out:
# VisiSet({'Bob', 'Alice', 'Elise', 'G', 'Fred', 'H', 'I', 'Carla', 'Diego', 'J'})

# %%
v.add('ZZZ')
v
# Out:
# VisiSet({'H', 'Fred', 'Carla', 'Bob', 'Alice', 'ZZZ', 'Elise', 'G', 'I', 'Diego', 'J'})
